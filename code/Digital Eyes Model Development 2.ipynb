# %%
import pandas as pd
import numpy as n
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('C:\\Users\\saira\\OneDrive\\Desktop\\DigitalEye\\dg.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Name                                    300 non-null    object
#  1   Age                                     300 non-null    int64
#  2   Sex                                     300 non-null    int64
#  3   wearables                               300 non-null    int64
#  4   Duration                                300 non-null    int64
#  5   onlineplatforms                         300 non-null    int64
#  6   Nature                                  300 non-null    int64
#  7   screenillumination                      300 non-null    int64
#  8   workingyears                            300 non-null    int64
#  9   hoursspentdailycurricular               300 non-null    int64
# ...

# %%
columns_to_drop = ['Name']
data.drop(columns=columns_to_drop, inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# Assuming you have your data in a DataFrame called 'data'
# Each row represents an individual, and columns represent features including Schimers1Lefteye, Schimers1righteye, Schimers2Lefteye, Schimers2righteye, and possibly others.

# Load your data
# Example:
# data = pd.read_csv('your_data.csv')

# Extract features and target variables
X = data.drop(['Schimers1Lefteye', 'Schimers1righteye', 'Schimers2Lefteye', 'Schimers2righteye'], axis=1) # Drop the target variables from features

# Assuming you have separate target variables for each eye
y_Schimers1Lefteye = data['Schimers1Lefteye']
y_Schimers1righteye = data['Schimers1righteye']
y_Schimers2Lefteye = data['Schimers2Lefteye']
y_Schimers2righteye = data['Schimers2righteye']

# Initialize and train the Random Forest regressors for each target variable
rf_classifier_Schimers1Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1Lefteye.fit(X, y_Schimers1Lefteye)

rf_classifier_Schimers1righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1righteye.fit(X, y_Schimers1righteye)

rf_classifier_Schimers2Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2Lefteye.fit(X, y_Schimers2Lefteye)

rf_classifier_Schimers2righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2righteye.fit(X, y_Schimers2righteye)

# If you want to use the full data to train and not split into training and testing sets, you can directly use the models to make predictions on new data.

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions for each target variable
y_pred_Schimers1Lefteye = rf_classifier_Schimers1Lefteye.predict(X)
y_pred_Schimers1righteye = rf_classifier_Schimers1righteye.predict(X)
y_pred_Schimers2Lefteye = rf_classifier_Schimers2Lefteye.predict(X)
y_pred_Schimers2righteye = rf_classifier_Schimers2righteye.predict(X)

# Compute evaluation metrics for each target variable
mae_Schimers1Lefteye = mean_absolute_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
mse_Schimers1Lefteye = mean_squared_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
r2_Schimers1Lefteye = r2_score(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)

mae_Schimers1righteye = mean_absolute_error(y_Schimers1righteye, y_pred_Schimers1righteye)
mse_Schimers1righteye = mean_squared_error(y_Schimers1righteye, y_pred_Schimers1righteye)
r2_Schimers1righteye = r2_score(y_Schimers1righteye, y_pred_Schimers1righteye)

mae_Schimers2Lefteye = mean_absolute_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
mse_Schimers2Lefteye = mean_squared_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
r2_Schimers2Lefteye = r2_score(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)

mae_Schimers2righteye = mean_absolute_error(y_Schimers2righteye, y_pred_Schimers2righteye)
mse_Schimers2righteye = mean_squared_error(y_Schimers2righteye, y_pred_Schimers2righteye)
r2_Schimers2righteye = r2_score(y_Schimers2righteye, y_pred_Schimers2righteye)

# Print evaluation metrics for each target variable
print("Schimers1Lefteye:")
print("MAE:", mae_Schimers1Lefteye)
print("MSE:", mse_Schimers1Lefteye)
print("R2 Score:", r2_Schimers1Lefteye)
print()

print("Schimers1righteye:")
print("MAE:", mae_Schimers1righteye)
print("MSE:", mse_Schimers1righteye)
print("R2 Score:", r2_Schimers1righteye)
print()

print("Schimers2Lefteye:")
print("MAE:", mae_Schimers2Lefteye)
print("MSE:", mse_Schimers2Lefteye)
print("R2 Score:", r2_Schimers2Lefteye)
print()

print("Schimers2righteye:")
print("MAE:", mae_Schimers2righteye)
print("MSE:", mse_Schimers2righteye)
print("R2 Score:", r2_Schimers2righteye)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions for each target variable
y_pred_Schimers1Lefteye = rf_classifier_Schimers1Lefteye.predict(X)
y_pred_Schimers1righteye = rf_classifier_Schimers1righteye.predict(X)
y_pred_Schimers2Lefteye = rf_classifier_Schimers2Lefteye.predict(X)
y_pred_Schimers2righteye = rf_classifier_Schimers2righteye.predict(X)

# Compute evaluation metrics for each target variable
mae_Schimers1Lefteye = mean_absolute_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
mse_Schimers1Lefteye = mean_squared_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
r2_Schimers1Lefteye = r2_score(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)

mae_Schimers1righteye = mean_absolute_error(y_Schimers1righteye, y_pred_Schimers1righteye)
mse_Schimers1righteye = mean_squared_error(y_Schimers1righteye, y_pred_Schimers1righteye)
r2_Schimers1righteye = r2_score(y_Schimers1righteye, y_pred_Schimers1righteye)

mae_Schimers2Lefteye = mean_absolute_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
mse_Schimers2Lefteye = mean_squared_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
r2_Schimers2Lefteye = r2_score(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)

mae_Schimers2righteye = mean_absolute_error(y_Schimers2righteye, y_pred_Schimers2righteye)
mse_Schimers2righteye = mean_squared_error(y_Schimers2righteye, y_pred_Schimers2righteye)
r2_Schimers2righteye = r2_score(y_Schimers2righteye, y_pred_Schimers2righteye)

# Print evaluation metrics for each target variable
print("Schimers1Lefteye:")
print("MAE:", mae_Schimers1Lefteye)
print("MSE:", mse_Schimers1Lefteye)
print("R2 Score:", r2_Schimers1Lefteye)
print()

print("Schimers1righteye:")
print("MAE:", mae_Schimers1righteye)
print("MSE:", mse_Schimers1righteye)
print("R2 Score:", r2_Schimers1righteye)
print()

print("Schimers2Lefteye:")
print("MAE:", mae_Schimers2Lefteye)
print("MSE:", mse_Schimers2Lefteye)
print("R2 Score:", r2_Schimers2Lefteye)
print()

print("Schimers2righteye:")
print("MAE:", mae_Schimers2righteye)
print("MSE:", mse_Schimers2righteye)
print("R2 Score:", r2_Schimers2righteye)
# Out:
# Schimers1Lefteye:
# MAE: 1.765018253968254
# MSE: 5.092485759387755
# R2 Score: 0.9094314258971026
#
# Schimers1righteye:
# MAE: 1.6313
# MSE: 4.625907000000001
# R2 Score: 0.9147346448004168
#
# Schimers2Lefteye:
# MAE: 1.681863492063492
# MSE: 4.552762606893424
# R2 Score: 0.9095264126080949
#
# Schimers2righteye:
# MAE: 1.4537333333333333
# MSE: 3.6725039999999995
# R2 Score: 0.9258712299273347

# %%
import pandas as pd
from sklearn.decomposition import PCA

# Initialize PCA
pca = PCA()

# Fit PCA to the data
pca.fit(X)

# Get the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
print(X.columns)
# Get the names of the columns in X
column_names = X.columns

# Create a DataFrame to hold the explained variance ratios and corresponding column names
explained_variance_df = pd.DataFrame({
    'Column_Name': column_names,
    'Explained_Variance_Ratio': explained_variance_ratio
})

# Sort DataFrame by explained variance ratio in descending order
explained_variance_df = explained_variance_df.sort_values(by='Explained_Variance_Ratio', ascending=False)

# Print the DataFrame
print(explained_variance_df)
# Set a threshold for the explained variance ratio (e.g., 1%)
threshold = 0.01

# Filter the DataFrame to keep only features with an explained variance ratio above the threshold
important_features = explained_variance_df[explained_variance_df['Explained_Variance_Ratio'] >= threshold]

# List the important features
important_features_list = important_features['Column_Name'].tolist()

# List the features to be dropped
features_to_drop = [col for col in column_names if col not in important_features_list]
print()
print("Features to be dropped:", features_to_drop)
# Out:
# Index(['Age', 'Sex', 'wearables', 'Duration', 'onlineplatforms', 'Nature',
#        'screenillumination', 'workingyears', 'hoursspentdailycurricular',
#        'hoursspentdailynoncurricular', 'Gadgetsused',
#        'levelofgadjetwithrespecttoeyes', 'Distancekeptbetweeneyesandgadjet',
#        'Avgnighttimeusageperday', 'Blinkingduringscreenusage',
#        'Difficultyinfocusingafterusingscreens', 'freqquencyofcomplaints',
#        'Severityofcomplaints', 'Ocularsymptomsobservedlately',
#        'Symptomsobservingatleasthalfofthetimes', 'Complaintsfrequency',
#        'frequencyofdryeyes'],
#       dtype='object')
#                                Column_Name  Explained_Variance_Ratio
# 0                                      Age                  0.318161
# 1                                      Sex                  0.249869
# 2                                wearables                  0.105911
# 3                                 Duration                  0.063812
# ...

# %%
columns_to_drop = ['frequencyofdryeyes']
data.drop(columns=columns_to_drop, inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# Assuming you have your data in a DataFrame called 'data'
# Each row represents an individual, and columns represent features including Schimers1Lefteye, Schimers1righteye, Schimers2Lefteye, Schimers2righteye, and possibly others.

# Load your data
# Example:
# data = pd.read_csv('your_data.csv')

# Extract features and target variables
X = data.drop(['Schimers1Lefteye', 'Schimers1righteye', 'Schimers2Lefteye', 'Schimers2righteye'], axis=1) # Drop the target variables from features

# Assuming you have separate target variables for each eye
y_Schimers1Lefteye = data['Schimers1Lefteye']
y_Schimers1righteye = data['Schimers1righteye']
y_Schimers2Lefteye = data['Schimers2Lefteye']
y_Schimers2righteye = data['Schimers2righteye']

# Initialize and train the Random Forest regressors for each target variable
rf_classifier_Schimers1Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1Lefteye.fit(X, y_Schimers1Lefteye)

rf_classifier_Schimers1righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1righteye.fit(X, y_Schimers1righteye)

rf_classifier_Schimers2Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2Lefteye.fit(X, y_Schimers2Lefteye)

rf_classifier_Schimers2righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2righteye.fit(X, y_Schimers2righteye)

# If you want to use the full data to train and not split into training and testing sets, you can directly use the models to make predictions on new data.

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions for each target variable
y_pred_Schimers1Lefteye = rf_classifier_Schimers1Lefteye.predict(X)
y_pred_Schimers1righteye = rf_classifier_Schimers1righteye.predict(X)
y_pred_Schimers2Lefteye = rf_classifier_Schimers2Lefteye.predict(X)
y_pred_Schimers2righteye = rf_classifier_Schimers2righteye.predict(X)

# Compute evaluation metrics for each target variable
mae_Schimers1Lefteye = mean_absolute_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
mse_Schimers1Lefteye = mean_squared_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
r2_Schimers1Lefteye = r2_score(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)

mae_Schimers1righteye = mean_absolute_error(y_Schimers1righteye, y_pred_Schimers1righteye)
mse_Schimers1righteye = mean_squared_error(y_Schimers1righteye, y_pred_Schimers1righteye)
r2_Schimers1righteye = r2_score(y_Schimers1righteye, y_pred_Schimers1righteye)

mae_Schimers2Lefteye = mean_absolute_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
mse_Schimers2Lefteye = mean_squared_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
r2_Schimers2Lefteye = r2_score(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)

mae_Schimers2righteye = mean_absolute_error(y_Schimers2righteye, y_pred_Schimers2righteye)
mse_Schimers2righteye = mean_squared_error(y_Schimers2righteye, y_pred_Schimers2righteye)
r2_Schimers2righteye = r2_score(y_Schimers2righteye, y_pred_Schimers2righteye)

# Print evaluation metrics for each target variable
print("Schimers1Lefteye:")
print("MAE:", mae_Schimers1Lefteye)
print("MSE:", mse_Schimers1Lefteye)
print("R2 Score:", r2_Schimers1Lefteye)
print()

print("Schimers1righteye:")
print("MAE:", mae_Schimers1righteye)
print("MSE:", mse_Schimers1righteye)
print("R2 Score:", r2_Schimers1righteye)
print()

print("Schimers2Lefteye:")
print("MAE:", mae_Schimers2Lefteye)
print("MSE:", mse_Schimers2Lefteye)
print("R2 Score:", r2_Schimers2Lefteye)
print()

print("Schimers2righteye:")
print("MAE:", mae_Schimers2righteye)
print("MSE:", mse_Schimers2righteye)
print("R2 Score:", r2_Schimers2righteye)
# Out:
# Schimers1Lefteye:
# MAE: 1.7485171428571429
# MSE: 4.946023108964474
# R2 Score: 0.9120362271739082
#
# Schimers1righteye:
# MAE: 1.6459333333333332
# MSE: 4.748565999999999
# R2 Score: 0.9124737772119794
#
# Schimers2Lefteye:
# MAE: 1.66639126984127
# MSE: 4.4452760362585035
# R2 Score: 0.9116624114469253
#
# Schimers2righteye:
# MAE: 1.4422333333333333
# MSE: 3.6890903333333336
# R2 Score: 0.9255364380550821

# %%
columns_to_drop = ['Complaintsfrequency']
data.drop(columns=columns_to_drop, inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# Assuming you have your data in a DataFrame called 'data'
# Each row represents an individual, and columns represent features including Schimers1Lefteye, Schimers1righteye, Schimers2Lefteye, Schimers2righteye, and possibly others.

# Load your data
# Example:
# data = pd.read_csv('your_data.csv')

# Extract features and target variables
X = data.drop(['Schimers1Lefteye', 'Schimers1righteye', 'Schimers2Lefteye', 'Schimers2righteye'], axis=1) # Drop the target variables from features

# Assuming you have separate target variables for each eye
y_Schimers1Lefteye = data['Schimers1Lefteye']
y_Schimers1righteye = data['Schimers1righteye']
y_Schimers2Lefteye = data['Schimers2Lefteye']
y_Schimers2righteye = data['Schimers2righteye']

# Initialize and train the Random Forest regressors for each target variable
rf_classifier_Schimers1Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1Lefteye.fit(X, y_Schimers1Lefteye)

rf_classifier_Schimers1righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1righteye.fit(X, y_Schimers1righteye)

rf_classifier_Schimers2Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2Lefteye.fit(X, y_Schimers2Lefteye)

rf_classifier_Schimers2righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2righteye.fit(X, y_Schimers2righteye)

# If you want to use the full data to train and not split into training and testing sets, you can directly use the models to make predictions on new data.

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions for each target variable
y_pred_Schimers1Lefteye = rf_classifier_Schimers1Lefteye.predict(X)
y_pred_Schimers1righteye = rf_classifier_Schimers1righteye.predict(X)
y_pred_Schimers2Lefteye = rf_classifier_Schimers2Lefteye.predict(X)
y_pred_Schimers2righteye = rf_classifier_Schimers2righteye.predict(X)

# Compute evaluation metrics for each target variable
mae_Schimers1Lefteye = mean_absolute_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
mse_Schimers1Lefteye = mean_squared_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
r2_Schimers1Lefteye = r2_score(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)

mae_Schimers1righteye = mean_absolute_error(y_Schimers1righteye, y_pred_Schimers1righteye)
mse_Schimers1righteye = mean_squared_error(y_Schimers1righteye, y_pred_Schimers1righteye)
r2_Schimers1righteye = r2_score(y_Schimers1righteye, y_pred_Schimers1righteye)

mae_Schimers2Lefteye = mean_absolute_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
mse_Schimers2Lefteye = mean_squared_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
r2_Schimers2Lefteye = r2_score(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)

mae_Schimers2righteye = mean_absolute_error(y_Schimers2righteye, y_pred_Schimers2righteye)
mse_Schimers2righteye = mean_squared_error(y_Schimers2righteye, y_pred_Schimers2righteye)
r2_Schimers2righteye = r2_score(y_Schimers2righteye, y_pred_Schimers2righteye)

# Print evaluation metrics for each target variable
print("Schimers1Lefteye:")
print("MAE:", mae_Schimers1Lefteye)
print("MSE:", mse_Schimers1Lefteye)
print("R2 Score:", r2_Schimers1Lefteye)
print()

print("Schimers1righteye:")
print("MAE:", mae_Schimers1righteye)
print("MSE:", mse_Schimers1righteye)
print("R2 Score:", r2_Schimers1righteye)
print()

print("Schimers2Lefteye:")
print("MAE:", mae_Schimers2Lefteye)
print("MSE:", mse_Schimers2Lefteye)
print("R2 Score:", r2_Schimers2Lefteye)
print()

print("Schimers2righteye:")
print("MAE:", mae_Schimers2righteye)
print("MSE:", mse_Schimers2righteye)
print("R2 Score:", r2_Schimers2righteye)
# Out:
# Schimers1Lefteye:
# MAE: 1.7442233333333332
# MSE: 5.004378894187453
# R2 Score: 0.9109983842602473
#
# Schimers1righteye:
# MAE: 1.6553333333333335
# MSE: 4.744130666666667
# R2 Score: 0.912555529887097
#
# Schimers2Lefteye:
# MAE: 1.6565214285714285
# MSE: 4.457796263318215
# R2 Score: 0.9114136065003774
#
# Schimers2righteye:
# MAE: 1.455166666666667
# MSE: 3.688681666666666
# R2 Score: 0.9255446869112766

# %%
columns_to_drop = ['Difficultyinfocusingafterusingscreens', 'freqquencyofcomplaints', 'Severityofcomplaints', 'Ocularsymptomsobservedlately', 'Symptomsobservingatleasthalfofthetimes']
data.drop(columns=columns_to_drop, inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# Assuming you have your data in a DataFrame called 'data'
# Each row represents an individual, and columns represent features including Schimers1Lefteye, Schimers1righteye, Schimers2Lefteye, Schimers2righteye, and possibly others.

# Load your data
# Example:
# data = pd.read_csv('your_data.csv')

# Extract features and target variables
X = data.drop(['Schimers1Lefteye', 'Schimers1righteye', 'Schimers2Lefteye', 'Schimers2righteye'], axis=1) # Drop the target variables from features

# Assuming you have separate target variables for each eye
y_Schimers1Lefteye = data['Schimers1Lefteye']
y_Schimers1righteye = data['Schimers1righteye']
y_Schimers2Lefteye = data['Schimers2Lefteye']
y_Schimers2righteye = data['Schimers2righteye']

# Initialize and train the Random Forest regressors for each target variable
rf_classifier_Schimers1Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1Lefteye.fit(X, y_Schimers1Lefteye)

rf_classifier_Schimers1righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1righteye.fit(X, y_Schimers1righteye)

rf_classifier_Schimers2Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2Lefteye.fit(X, y_Schimers2Lefteye)

rf_classifier_Schimers2righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2righteye.fit(X, y_Schimers2righteye)

# If you want to use the full data to train and not split into training and testing sets, you can directly use the models to make predictions on new data.

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions for each target variable
y_pred_Schimers1Lefteye = rf_classifier_Schimers1Lefteye.predict(X)
y_pred_Schimers1righteye = rf_classifier_Schimers1righteye.predict(X)
y_pred_Schimers2Lefteye = rf_classifier_Schimers2Lefteye.predict(X)
y_pred_Schimers2righteye = rf_classifier_Schimers2righteye.predict(X)

# Compute evaluation metrics for each target variable
mae_Schimers1Lefteye = mean_absolute_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
mse_Schimers1Lefteye = mean_squared_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
r2_Schimers1Lefteye = r2_score(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)

mae_Schimers1righteye = mean_absolute_error(y_Schimers1righteye, y_pred_Schimers1righteye)
mse_Schimers1righteye = mean_squared_error(y_Schimers1righteye, y_pred_Schimers1righteye)
r2_Schimers1righteye = r2_score(y_Schimers1righteye, y_pred_Schimers1righteye)

mae_Schimers2Lefteye = mean_absolute_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
mse_Schimers2Lefteye = mean_squared_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
r2_Schimers2Lefteye = r2_score(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)

mae_Schimers2righteye = mean_absolute_error(y_Schimers2righteye, y_pred_Schimers2righteye)
mse_Schimers2righteye = mean_squared_error(y_Schimers2righteye, y_pred_Schimers2righteye)
r2_Schimers2righteye = r2_score(y_Schimers2righteye, y_pred_Schimers2righteye)

# Print evaluation metrics for each target variable
print("Schimers1Lefteye:")
print("MAE:", mae_Schimers1Lefteye)
print("MSE:", mse_Schimers1Lefteye)
print("R2 Score:", r2_Schimers1Lefteye)
print()

print("Schimers1righteye:")
print("MAE:", mae_Schimers1righteye)
print("MSE:", mse_Schimers1righteye)
print("R2 Score:", r2_Schimers1righteye)
print()

print("Schimers2Lefteye:")
print("MAE:", mae_Schimers2Lefteye)
print("MSE:", mse_Schimers2Lefteye)
print("R2 Score:", r2_Schimers2Lefteye)
print()

print("Schimers2righteye:")
print("MAE:", mae_Schimers2righteye)
print("MSE:", mse_Schimers2righteye)
print("R2 Score:", r2_Schimers2righteye)
# Out:
# Schimers1Lefteye:
# MAE: 2.290395634920635
# MSE: 8.133717207334655
# R2 Score: 0.855343892073433
#
# Schimers1righteye:
# MAE: 2.192821547619048
# MSE: 7.605395003267773
# R2 Score: 0.8598163113986593
#
# Schimers2Lefteye:
# MAE: 2.1968413095238097
# MSE: 7.422577118685279
# R2 Score: 0.8524967722666397
#
# Schimers2righteye:
# MAE: 2.1119841534391535
# MSE: 7.294407868765223
# R2 Score: 0.8527638135397708

# %%
import pandas as pd
from sklearn.decomposition import PCA

# Initialize PCA
pca = PCA()

# Fit PCA to the data
pca.fit(X)

# Get the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
print(X.columns)
# Get the names of the columns in X
column_names = X.columns

# Create a DataFrame to hold the explained variance ratios and corresponding column names
explained_variance_df = pd.DataFrame({
    'Column_Name': column_names,
    'Explained_Variance_Ratio': explained_variance_ratio
})

# Sort DataFrame by explained variance ratio in descending order
explained_variance_df = explained_variance_df.sort_values(by='Explained_Variance_Ratio', ascending=False)

# Print the DataFrame
print(explained_variance_df)
# Set a threshold for the explained variance ratio (e.g., 1%)
threshold = 0.01

# Filter the DataFrame to keep only features with an explained variance ratio above the threshold
important_features = explained_variance_df[explained_variance_df['Explained_Variance_Ratio'] >= threshold]

# List the important features
important_features_list = important_features['Column_Name'].tolist()

# List the features to be dropped
features_to_drop = [col for col in column_names if col not in important_features_list]
print()
print("Features to be dropped:", features_to_drop)
# Out:
# Index(['Age', 'Sex', 'wearables', 'Duration', 'onlineplatforms', 'Nature',
#        'screenillumination', 'workingyears', 'hoursspentdailycurricular',
#        'hoursspentdailynoncurricular', 'Gadgetsused',
#        'levelofgadjetwithrespecttoeyes', 'Distancekeptbetweeneyesandgadjet',
#        'Avgnighttimeusageperday', 'Blinkingduringscreenusage'],
#       dtype='object')
#                          Column_Name  Explained_Variance_Ratio
# 0                                Age                  0.502866
# 1                                Sex                  0.166806
# 2                          wearables                  0.092338
# 3                           Duration                  0.044718
# 4                    onlineplatforms                  0.032919
# 5                             Nature                  0.028683
# 6                 screenillumination                  0.024685
# 7                       workingyears                  0.020106
# ...

# %%
columns_to_drop = ['Avgnighttimeusageperday', 'Blinkingduringscreenusage']
data.drop(columns=columns_to_drop, inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# Assuming you have your data in a DataFrame called 'data'
# Each row represents an individual, and columns represent features including Schimers1Lefteye, Schimers1righteye, Schimers2Lefteye, Schimers2righteye, and possibly others.

# Load your data
# Example:
# data = pd.read_csv('your_data.csv')

# Extract features and target variables
X = data.drop(['Schimers1Lefteye', 'Schimers1righteye', 'Schimers2Lefteye', 'Schimers2righteye'], axis=1) # Drop the target variables from features

# Assuming you have separate target variables for each eye
y_Schimers1Lefteye = data['Schimers1Lefteye']
y_Schimers1righteye = data['Schimers1righteye']
y_Schimers2Lefteye = data['Schimers2Lefteye']
y_Schimers2righteye = data['Schimers2righteye']

# Initialize and train the Random Forest regressors for each target variable
rf_classifier_Schimers1Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1Lefteye.fit(X, y_Schimers1Lefteye)

rf_classifier_Schimers1righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers1righteye.fit(X, y_Schimers1righteye)

rf_classifier_Schimers2Lefteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2Lefteye.fit(X, y_Schimers2Lefteye)

rf_classifier_Schimers2righteye = RandomForestRegressor(n_estimators=100, random_state=42)
rf_classifier_Schimers2righteye.fit(X, y_Schimers2righteye)

# If you want to use the full data to train and not split into training and testing sets, you can directly use the models to make predictions on new data.

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions for each target variable
y_pred_Schimers1Lefteye = rf_classifier_Schimers1Lefteye.predict(X)
y_pred_Schimers1righteye = rf_classifier_Schimers1righteye.predict(X)
y_pred_Schimers2Lefteye = rf_classifier_Schimers2Lefteye.predict(X)
y_pred_Schimers2righteye = rf_classifier_Schimers2righteye.predict(X)

# Compute evaluation metrics for each target variable
mae_Schimers1Lefteye = mean_absolute_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
mse_Schimers1Lefteye = mean_squared_error(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)
r2_Schimers1Lefteye = r2_score(y_Schimers1Lefteye, y_pred_Schimers1Lefteye)

mae_Schimers1righteye = mean_absolute_error(y_Schimers1righteye, y_pred_Schimers1righteye)
mse_Schimers1righteye = mean_squared_error(y_Schimers1righteye, y_pred_Schimers1righteye)
r2_Schimers1righteye = r2_score(y_Schimers1righteye, y_pred_Schimers1righteye)

mae_Schimers2Lefteye = mean_absolute_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
mse_Schimers2Lefteye = mean_squared_error(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)
r2_Schimers2Lefteye = r2_score(y_Schimers2Lefteye, y_pred_Schimers2Lefteye)

mae_Schimers2righteye = mean_absolute_error(y_Schimers2righteye, y_pred_Schimers2righteye)
mse_Schimers2righteye = mean_squared_error(y_Schimers2righteye, y_pred_Schimers2righteye)
r2_Schimers2righteye = r2_score(y_Schimers2righteye, y_pred_Schimers2righteye)

# Print evaluation metrics for each target variable
print("Schimers1Lefteye:")
print("MAE:", mae_Schimers1Lefteye)
print("MSE:", mse_Schimers1Lefteye)
print("R2 Score:", r2_Schimers1Lefteye)
print()

print("Schimers1righteye:")
print("MAE:", mae_Schimers1righteye)
print("MSE:", mse_Schimers1righteye)
print("R2 Score:", r2_Schimers1righteye)
print()

print("Schimers2Lefteye:")
print("MAE:", mae_Schimers2Lefteye)
print("MSE:", mse_Schimers2Lefteye)
print("R2 Score:", r2_Schimers2Lefteye)
print()

print("Schimers2righteye:")
print("MAE:", mae_Schimers2righteye)
print("MSE:", mse_Schimers2righteye)
print("R2 Score:", r2_Schimers2righteye)
# Out:
# Schimers1Lefteye:
# MAE: 2.3623708730158732
# MSE: 8.786153452718255
# R2 Score: 0.8437404780965729
#
# Schimers1righteye:
# MAE: 2.2983560185185183
# MSE: 8.054735583122795
# R2 Score: 0.8515340039188667
#
# Schimers2Lefteye:
# MAE: 2.2874997619047623
# MSE: 7.946474063351285
# R2 Score: 0.8420857668837048
#
# Schimers2righteye:
# MAE: 2.186692671957672
# MSE: 7.75179817923291
# R2 Score: 0.8435314801895214

# %%
import pandas as pd
from sklearn.decomposition import PCA

# Initialize PCA
pca = PCA()

# Fit PCA to the data
pca.fit(X)

# Get the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
print(X.columns)
# Get the names of the columns in X
column_names = X.columns

# Create a DataFrame to hold the explained variance ratios and corresponding column names
explained_variance_df = pd.DataFrame({
    'Column_Name': column_names,
    'Explained_Variance_Ratio': explained_variance_ratio
})

# Sort DataFrame by explained variance ratio in descending order
explained_variance_df = explained_variance_df.sort_values(by='Explained_Variance_Ratio', ascending=False)

# Print the DataFrame
print(explained_variance_df)
# Set a threshold for the explained variance ratio (e.g., 1%)
threshold = 0.01

# Filter the DataFrame to keep only features with an explained variance ratio above the threshold
important_features = explained_variance_df[explained_variance_df['Explained_Variance_Ratio'] >= threshold]

# List the important features
important_features_list = important_features['Column_Name'].tolist()

# List the features to be dropped
features_to_drop = [col for col in column_names if col not in important_features_list]
print()
print("Features to be dropped:", features_to_drop)
# Out:
# Index(['Age', 'Sex', 'wearables', 'Duration', 'onlineplatforms', 'Nature',
#        'screenillumination', 'workingyears', 'hoursspentdailycurricular',
#        'hoursspentdailynoncurricular', 'Gadgetsused',
#        'levelofgadjetwithrespecttoeyes', 'Distancekeptbetweeneyesandgadjet'],
#       dtype='object')
#                          Column_Name  Explained_Variance_Ratio
# 0                                Age                  0.540361
# 1                                Sex                  0.173182
# 2                          wearables                  0.088964
# 3                           Duration                  0.038598
# 4                    onlineplatforms                  0.029763
# 5                             Nature                  0.025561
# 6                 screenillumination                  0.021481
# 7                       workingyears                  0.020142
# 8          hoursspentdailycurricular                  0.017501
# ...
